# %%
from google.colab import drive
drive.mount('/content/drive//e7-htr-currernt(1).csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('e7-htr-currernt (1).csv')
df=df.dropna()
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-379199af661e> in <cell line: 1>()
# ----> 1 df = pd.read_csv('e7-htr-currernt (1).csv')
#       2 df=df.dropna()
#       3 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
dff = pd.DataFrame(df['Timestamp'].str.split(' ',expand=True))
df['Timestamp']=dff.drop([1],axis=1)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df[df['Timestamp']==df['Timestamp'][0]]

# %%
(df.groupby(['Timestamp'], as_index=False)).mean()

# %%
df=(df.groupby(['Timestamp'], as_index=False)).var()
df

# %%
df_1=df[df['HT R Phase Current']!=0]
df_1

# %%
df_0=df[df['HT R Phase Current']==0]
df_0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e297f31ef569> in <cell line: 1>()
# ----> 1 df_0=df[df['HT R Phase Current']==0]
#       2 df_0
#
# NameError: name 'df' is not defined
